# %%
import pandas as pd
import glob
import os

# %%
# Select the path to all datasets with the name "_clean_dataset.csv"
files = os.path.join("cleaning_code/csv_data/", "*_clean_dataset.csv")

# %%
files = glob.glob(files)

# %%
# Merge all the datasets together
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df
# Out:
#      Years     FIPS       County   Deaths  % Fair or Poor Health  \
# 0     2011  36001.0       Albany   2948.0                   12.0
# 1     2011  36003.0     Allegany    565.0                   16.0
# 2     2011  36005.0        Bronx  14630.0                   26.0
# 3     2011  36007.0       Broome   2243.0                   13.0
# 4     2011  36009.0  Cattaraugus   1007.0                   20.0
# ..     ...      ...          ...      ...                    ...
# 725   2022  36115.0   Washington    882.0                   18.0
# 726   2022  36117.0        Wayne   1248.0                   17.0
# 727   2022  36119.0  Westchester   8329.0                   16.0
# 728   2022  36121.0      Wyoming    498.0                   18.0
# 729   2022  36123.0        Yates    339.0                   18.0
#
#      % Low birthweight  Food Environment Index  # Driving Deaths  # Uninsured  \
# 0                  8.0                     0.0               0.0          0.0
# 1                  6.7                     0.0               0.0          0.0
# 2                  9.7                     0.0               0.0          0.0
# 3                  7.6                     0.0               0.0          0.0
# 4                  6.9                     0.0               0.0          0.0
# ..                 ...                     ...               ...          ...
# 725                7.0                     8.5              29.0       2344.0
# 726                7.0                     8.6              56.0       3067.0
# 727                8.0                     9.3             163.0      45099.0
# 728                7.0                     8.4              19.0       1289.0
# 729                4.0                     8.9              10.0       1520.0
#
#      Mental Health Provider Ratio
# 0                        0.002985
# 1                        0.000243
# 2                        0.000957
# 3                        0.000262
# 4                        0.000075
# ..                            ...
# 725                      0.001502
# 726                      0.001130
# 727                      0.004274
# 728                      0.002304
# 729                      0.001171
#
# [730 rows x 10 columns]

# %%
# Check if the columns have any NaN
df.isnull().sum()
# Out:
# Years                           0
# FIPS                            0
# County                          0
# Deaths                          3
# % Fair or Poor Health           0
# % Low birthweight               0
# Food Environment Index          0
# # Driving Deaths                0
# # Uninsured                     0
# Mental Health Provider Ratio    0
# dtype: int64

# %%
# Convert all the NaN into 0
df = df.fillna(0)

# %%
# Checking if there are any NaN left
df.isnull().sum()
# Out:
# Years                           0
# FIPS                            0
# County                          0
# Deaths                          0
# % Fair or Poor Health           0
# % Low birthweight               0
# Food Environment Index          0
# # Driving Deaths                0
# # Uninsured                     0
# Mental Health Provider Ratio    0
# dtype: int64

# %%
# Checking the dtypes of the dataset 
df.dtypes
# Out:
# Years                             int64
# FIPS                            float64
# County                           object
# Deaths                          float64
# % Fair or Poor Health           float64
# % Low birthweight               float64
# Food Environment Index          float64
# # Driving Deaths                float64
# # Uninsured                     float64
# Mental Health Provider Ratio    float64
# dtype: object

# %%
# Chaning selected columns from float to int
df = df.astype({"FIPS":"int",
                        "Years":"int",
                        "Deaths":"int",
                        "% Fair or Poor Health":"int",
                        "% Low birthweight":"int",
                        "# Driving Deaths":"int",
                        "# Uninsured":"int"})
df.dtypes
# Out:
# Years                             int32
# FIPS                              int32
# County                           object
# Deaths                            int32
# % Fair or Poor Health             int32
# % Low birthweight                 int32
# Food Environment Index          float64
# # Driving Deaths                  int32
# # Uninsured                       int32
# Mental Health Provider Ratio    float64
# dtype: object

# %%
# Testing the dataset
df[df['County'] == 'Albany']
# Out:
#      Years   FIPS  County  Deaths  % Fair or Poor Health  % Low birthweight  \
# 0     2011  36001  Albany    2948                     12                  8
# 59    2012  36001  Albany    2859                     12                  8
# 118   2013  36001  Albany    2886                     13                  8
# 176   2014  36001  Albany    2886                     13                  8
# 236   2015  36001  Albany    2947                     13                  8
# 296   2016  36001  Albany    3013                     12                  9
# 358   2017  36001  Albany    2996                     12                  9
# 420   2018  36001  Albany    3047                     13                  8
# 482   2019  36001  Albany    3202                     13                  8
# 544   2020  36001  Albany    3307                     14                  8
# 606   2021  36001  Albany    3336                     13                  8
# 668   2022  36001  Albany    3545                     15                  8
#
#      Food Environment Index  # Driving Deaths  # Uninsured  \
# 0                       0.0                 0            0
# 59                      0.0               143        23381
# 118                     0.0               148        25221
# 176                     8.0                92        22962
# 236                     7.9                87        23634
# 296                     7.7                91        21914
# 358                     7.7                97        18101
# 420                     8.0                99        13476
# 482                     8.1               100        10741
# 544                     8.0               105        10808
# 606                     8.4                95        10070
# 668                     8.3                91         9639
#
#      Mental Health Provider Ratio
# 0                        0.002985
# 59                       0.002985
# 118                      0.000998
# 176                      0.002252
# 236                      0.002710
# 296                      0.002882
# 358                      0.003021
# 420                      0.003155
# 482                      0.003344
# 544                      0.003559
# 606                      0.003759
# 668                      0.004000

# %%
df[df['Deaths'] == 0]
# Out:
#      Years   FIPS    County  Deaths  % Fair or Poor Health  % Low birthweight  \
# 564   2020  36041  Hamilton       0                     14                  5
# 626   2021  36041  Hamilton       0                     17                  6
# 688   2022  36041  Hamilton       0                     20                  6
#
#      Food Environment Index  # Driving Deaths  # Uninsured  \
# 564                     7.7                 1          210
# 626                     7.4                 4          191
# 688                     7.1                 4          218
#
#      Mental Health Provider Ratio
# 564                      0.000677
# 626                      0.000679
# 688                      0.000691

# %%
deaths = df['# Driving Deaths'].sum()
deaths
# Out:
# 69828

# %%
# Saving the new and cleaned dataset
file_path = "complete_dataset.csv"
df.to_csv(file_path, index=False )
