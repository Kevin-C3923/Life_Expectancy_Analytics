# %%
import pandas as pd

# %%
# Reading in Data
df = pd.read_csv('csv_data/2022_County_Health_Rankings_New_York_Data.csv')
df
# Out:
#      FIPS     State       County Unreliable    Deaths  \
# 0   36000  New York          NaN        NaN  213529.0
# 1   36001  New York       Albany        NaN    3545.0
# 2   36003  New York     Allegany        NaN     646.0
# 3   36005  New York        Bronx        NaN   18665.0
# 4   36007  New York       Broome        NaN    2598.0
# ..    ...       ...          ...        ...       ...
# 58  36115  New York   Washington        NaN     882.0
# 59  36117  New York        Wayne        NaN    1248.0
# 60  36119  New York  Westchester        NaN    8329.0
# 61  36121  New York      Wyoming        NaN     498.0
# 62  36123  New York        Yates        NaN     339.0
#
#     Years of Potential Life Lost Rate  95% CI - Low  95% CI - High  Z-Score  \
# 0                              5952.0        5914.0         5991.0      NaN
# 1                              6525.0        6186.0         6865.0    -0.18
# 2                              7085.0        6185.0         7985.0     0.34
# ...

# %%
# Selecting the columns we only want
select_df = df[['FIPS', 'County', 'Deaths', '% Fair or Poor Health', '% Low birthweight', 
            'Food Environment Index', '# Driving Deaths', '# Uninsured', 'Mental Health Provider Ratio']]
select_df
# Out:
#      FIPS       County    Deaths  % Fair or Poor Health  % Low birthweight  \
# 0   36000          NaN  213529.0                     16                  8
# 1   36001       Albany    3545.0                     15                  8
# 2   36003     Allegany     646.0                     18                  7
# 3   36005        Bronx   18665.0                     30                 10
# 4   36007       Broome    2598.0                     19                  8
# ..    ...          ...       ...                    ...                ...
# 58  36115   Washington     882.0                     18                  7
# 59  36117        Wayne    1248.0                     17                  7
# 60  36119  Westchester    8329.0                     16                  8
# 61  36121      Wyoming     498.0                     18                  7
# 62  36123        Yates     339.0                     18                  4
#
#     Food Environment Index  # Driving Deaths  # Uninsured  \
# ...

# %%
# Removing the first row that was NaN 
select_df = select_df.drop(labels=0, axis=0)
select_df
# Out:
#      FIPS       County   Deaths  % Fair or Poor Health  % Low birthweight  \
# 1   36001       Albany   3545.0                     15                  8
# 2   36003     Allegany    646.0                     18                  7
# 3   36005        Bronx  18665.0                     30                 10
# 4   36007       Broome   2598.0                     19                  8
# 5   36009  Cattaraugus   1224.0                     20                  8
# ..    ...          ...      ...                    ...                ...
# 58  36115   Washington    882.0                     18                  7
# 59  36117        Wayne   1248.0                     17                  7
# 60  36119  Westchester   8329.0                     16                  8
# 61  36121      Wyoming    498.0                     18                  7
# 62  36123        Yates    339.0                     18                  4
#
#     Food Environment Index  # Driving Deaths  # Uninsured  \
# ...

# %%
# The the year for the dataset
select_df["Years"] = "2022"
select_df
# Out:
#      FIPS       County   Deaths  % Fair or Poor Health  % Low birthweight  \
# 1   36001       Albany   3545.0                     15                  8
# 2   36003     Allegany    646.0                     18                  7
# 3   36005        Bronx  18665.0                     30                 10
# 4   36007       Broome   2598.0                     19                  8
# 5   36009  Cattaraugus   1224.0                     20                  8
# ..    ...          ...      ...                    ...                ...
# 58  36115   Washington    882.0                     18                  7
# 59  36117        Wayne   1248.0                     17                  7
# 60  36119  Westchester   8329.0                     16                  8
# 61  36121      Wyoming    498.0                     18                  7
# 62  36123        Yates    339.0                     18                  4
#
#     Food Environment Index  # Driving Deaths  # Uninsured  \
# ...

# %%
# Reorganizing the dataset
clean_data = select_df[['Years', 'FIPS', 'County', 'Deaths', '% Fair or Poor Health', '% Low birthweight', 
            'Food Environment Index', '# Driving Deaths', '# Uninsured', 'Mental Health Provider Ratio']]
clean_data
# Out:
#    Years   FIPS       County   Deaths  % Fair or Poor Health  \
# 1   2022  36001       Albany   3545.0                     15
# 2   2022  36003     Allegany    646.0                     18
# 3   2022  36005        Bronx  18665.0                     30
# 4   2022  36007       Broome   2598.0                     19
# 5   2022  36009  Cattaraugus   1224.0                     20
# ..   ...    ...          ...      ...                    ...
# 58  2022  36115   Washington    882.0                     18
# 59  2022  36117        Wayne   1248.0                     17
# 60  2022  36119  Westchester   8329.0                     16
# 61  2022  36121      Wyoming    498.0                     18
# 62  2022  36123        Yates    339.0                     18
#
#     % Low birthweight  Food Environment Index  # Driving Deaths  # Uninsured  \
# 1                   8                     8.3                91         9639
# ...

# %%
clean_data.dtypes
# Out:
# Years                            object
# FIPS                              int64
# County                           object
# Deaths                          float64
# % Fair or Poor Health             int64
# % Low birthweight                 int64
# Food Environment Index          float64
# # Driving Deaths                  int64
# # Uninsured                       int64
# Mental Health Provider Ratio     object
# dtype: object

# %%
# Spliting the Mental Health Provider Ratio 
changing = clean_data['Mental Health Provider Ratio'].str.split(':', expand=True)
changing.dtypes
# Out:
# 0    object
# 1    object
# dtype: object

# %%
# Converting the string into int
changing = changing.astype('int')

# %%
# Changing the Mental Health Provider Ratio into a int value
clean_data['Mental Health Provider Ratio'] = changing[1]/changing[0]
clean_data
# Out:
#    Years   FIPS       County   Deaths  % Fair or Poor Health  \
# 1   2022  36001       Albany   3545.0                     15
# 2   2022  36003     Allegany    646.0                     18
# 3   2022  36005        Bronx  18665.0                     30
# 4   2022  36007       Broome   2598.0                     19
# 5   2022  36009  Cattaraugus   1224.0                     20
# ..   ...    ...          ...      ...                    ...
# 58  2022  36115   Washington    882.0                     18
# 59  2022  36117        Wayne   1248.0                     17
# 60  2022  36119  Westchester   8329.0                     16
# 61  2022  36121      Wyoming    498.0                     18
# 62  2022  36123        Yates    339.0                     18
#
#     % Low birthweight  Food Environment Index  # Driving Deaths  # Uninsured  \
# 1                   8                     8.3                91         9639
# ...

# %%
# Saving the new and cleaned dataset
file_path = "csv_data/2022_clean_dataset.csv"
clean_data.to_csv(file_path, index=False )
