# %%
#Import dependencies
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine

# %%
#Import password from config.py file
from config import db_password

# %%
#Create database engine
"postgresql://[user]:[password]@[location]:[port]/[database]"
#Connection string for local server
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Life_Expectancy_Analytics"

# %%
#Create the database engine
engine = create_engine(db_string)

# %%
# Reading in census population data
CP = pd.read_csv('2020_Census_Population.csv')
CP.head()
# Out:
#         County  population
# 0       Albany      314848
# 1     Allegany       46456
# 2        Bronx     1472654
# 3       Broome      198683
# 4  Cattaraugus       77042

# %%
# Reading in health factors data
HF = pd.read_csv('complete_dataset2.csv')
HF.head()
# Out:
#    Years   FIPS       County  Deaths  Fair_or_Poor_Health_Percent  \
# 0   2011  36001       Albany    2948                           12
# 1   2011  36003     Allegany     565                           16
# 2   2011  36005        Bronx   14630                           26
# 3   2011  36007       Broome    2243                           13
# 4   2011  36009  Cattaraugus    1007                           20
#
#    Low_birthweight_Percent  Food_Environment_Index  Driving_Deaths_Number  \
# 0                        8                     0.0                      0
# 1                        6                     0.0                      0
# 2                        9                     0.0                      0
# 3                        7                     0.0                      0
# 4                        6                     0.0                      0
#
#    Uninsured_Number  Mental_Health_Provider_Ratio
# 0                 0                      0.002985
# ...

# %%
# Reading in Population to Factors Ratios
PFR = pd.read_csv('merged_pop_df.csv')
PFR.head()
# Out:
#    Unnamed: 0       County  Fair_or_Poor_Health_Percent  \
# 0           0       Albany                    12.916667
# 1           1     Allegany                    15.500000
# 2           2        Bronx                    26.666667
# 3           3       Broome                    15.083333
# 4           4  Cattaraugus                    18.250000
#
#    Low_birthweight_Percent  Food_Environment_Index  \
# 0                 8.166667                6.008333
# 1                 6.833333                6.150000
# 2                 9.416667                5.491667
# 3                 7.750000                5.916667
# 4                 7.333333                6.133333
#
#    Mental_Health_Provider_Ratio  Death_Ratio  Driving_Death_Ratio  \
# 0                      0.002971     0.009786             0.000304
# 1                      0.001483     0.012085             0.000529
# 2                      0.001508     0.010105             0.000165
# ...

# %%
# Merge the Census data with Population to Factors Ratios
CPR= pd.merge(CP, PFR, 
                   on='County', 
                   how='inner')
CPR.head()
# Out:
#         County  population  Unnamed: 0  Fair_or_Poor_Health_Percent  \
# 0       Albany      314848           0                    12.916667
# 1     Allegany       46456           1                    15.500000
# 2        Bronx     1472654           2                    26.666667
# 3       Broome      198683           3                    15.083333
# 4  Cattaraugus       77042           4                    18.250000
#
#    Low_birthweight_Percent  Food_Environment_Index  \
# 0                 8.166667                6.008333
# 1                 6.833333                6.150000
# 2                 9.416667                5.491667
# 3                 7.750000                5.916667
# 4                 7.333333                6.133333
#
#    Mental_Health_Provider_Ratio  Death_Ratio  Driving_Death_Ratio  \
# 0                      0.002971     0.009786             0.000304
# 1                      0.001483     0.012085             0.000529
# ...

# %%
clean_CPR = CPR[['County','population','Fair_or_Poor_Health_Percent','Low_birthweight_Percent','Food_Environment_Index','Mental_Health_Provider_Ratio','Death_Ratio','Driving_Death_Ratio','Uninsured_Ratio']]
clean_CPR.head()
# Out:
#         County  population  Fair_or_Poor_Health_Percent  \
# 0       Albany      314848                    12.916667
# 1     Allegany       46456                    15.500000
# 2        Bronx     1472654                    26.666667
# 3       Broome      198683                    15.083333
# 4  Cattaraugus       77042                    18.250000
#
#    Low_birthweight_Percent  Food_Environment_Index  \
# 0                 8.166667                6.008333
# 1                 6.833333                6.150000
# 2                 9.416667                5.491667
# 3                 7.750000                5.916667
# 4                 7.333333                6.133333
#
#    Mental_Health_Provider_Ratio  Death_Ratio  Driving_Death_Ratio  \
# 0                      0.002971     0.009786             0.000304
# 1                      0.001483     0.012085             0.000529
# 2                      0.001508     0.010105             0.000165
# ...
